# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/phili/Desktop/Most-Recent-Cohorts-All-Data-Elements (2).csv", delimiter = ',')

# df.head(5)
df.info()
# Out:
# C:\Users\phili\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (31,1608,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1640,1643,1648,1657,1666,1669,1674,1683,1688,1689,1690,1691,1692,1697,1700,1703,1704,1705,1706,1707,1726,1727,1728,1729,1815,1817,1823,1830,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Columns: 1977 entries, UNITID to OMENRUP_PARTTIME_POOLED_SUPP
# dtypes: float64(617), int64(14), object(1346)
# memory usage: 107.3+ MB

# %%
new = df.rename(columns = {  "UNITID":"University ID","CIP14BACHL":"B.S Engineering","CIP27BACHL":"B.S Math","CIP11BACHL":"B.S Computer Science",
                           "CIP41BACHL":"B.S Science and Tech","REGION":"Region","FEMALE":"Share of Female","UGDS":"Enrollment of UnderGrad","UG":
                           "UnderGrad Population","MN_EARN_WNE_INC1_P6":"Mean Earning After 6 yrs of Grad (0-30k)",
                           "MN_EARN_WNE_INC2_P6":"Mean Earning After 6 yrs of Grad(30-75k)","MN_EARN_WNE_INC3_P6":
                           "Mean Earning After 6 yrs of Grad(75k +)","MN_EARN_WNE_INC1_P8":"Mean Earning After 10 yrs of Grad (0-30k)",
                           "MN_EARN_WNE_INC2_P8":"Mean Earning After 6 yrs of Grad(30-75k)","MN_EARN_WNE_INC3_P8":"Mean Earning After 6 yrs of Grad(75k +)",
                           "MN_EARN_WNE_INC1_P10":"Mean Earning After 10 yrs of Grad (0-30k)","MN_EARN_WNE_INC2_P10":"Mean Earning After 10 yrs of Grad(30-75k)",
                           "MN_EARN_WNE_INC3_P10":"Mean Earning After 10 yrs of Grad(75k +)", })
new.head(5)
# Out:
#    University ID    OPEID  OPEID6                               INSTNM  \
# 0         100654   100200    1002             Alabama A & M University
# 1         100663   105200    1052  University of Alabama at Birmingham
# 2         100690  2503400   25034                   Amridge University
# 3         100706   105500    1055  University of Alabama in Huntsville
# 4         100724   100500    1005             Alabama State University
#
#          CITY STABBR         ZIP  \
# 0      Normal     AL       35762
# 1  Birmingham     AL  35294-0110
# 2  Montgomery     AL  36117-3553
# 3  Huntsville     AL       35899
# 4  Montgomery     AL  36104-0271
#
#                                         ACCREDAGENCY  \
# 0  Southern Association of Colleges and Schools C...
# 1  Southern Association of Colleges and Schools C...
# 2  Southern Association of Colleges and Schools C...
# 3  Southern Association of Colleges and Schools C...
# 4  Southern Association of Colleges and Schools C...
#
# ...

# %%
# list(new.columns.values)
Data_df = new[['University ID','B.S Engineering','B.S Math','B.S Computer Science','B.S Science and Tech','Region','Share of Female','Enrollment of UnderGrad','UnderGrad Population',
'Mean Earning After 6 yrs of Grad (0-30k)','Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)','Mean Earning After 10 yrs of Grad (0-30k)'
,'Mean Earning After 10 yrs of Grad(30-75k)',
'Mean Earning After 10 yrs of Grad(75k +)']]

Data_df.head()
# Out:
#    University ID  B.S Engineering  B.S Math  B.S Computer Science  \
# 0         100654              1.0       1.0                   1.0
# 1         100663              1.0       1.0                   1.0
# 2         100690              0.0       0.0                   0.0
# 3         100706              1.0       1.0                   1.0
# 4         100724              1.0       1.0                   1.0
#
#    B.S Science and Tech  Region Share of Female  Enrollment of UnderGrad  \
# 0                   0.0       5     0.564030132                   4824.0
# 1                   0.0       5      0.63909074                  12866.0
# 2                   0.0       5     0.648648649                    322.0
# 3                   0.0       5     0.476349937                   6917.0
# 4                   0.0       5      0.61341853                   4189.0
#
#    UnderGrad Population Mean Earning After 6 yrs of Grad (0-30k)  \
# ...

# %%
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Data columns (total 15 columns):
# University ID                                7112 non-null int64
# B.S Engineering                              6664 non-null float64
# B.S Math                                     6664 non-null float64
# B.S Computer Science                         6664 non-null float64
# B.S Science and Tech                         6664 non-null float64
# Region                                       7112 non-null int64
# Share of Female                              6741 non-null object
# Enrollment of UnderGrad                      6364 non-null float64
# UnderGrad Population                         4387 non-null float64
# Mean Earning After 6 yrs of Grad (0-30k)     5887 non-null object
# Mean Earning After 6 yrs of Grad(30-75k)     5887 non-null object
# Mean Earning After 6 yrs of Grad(75k +)      5887 non-null object
# ...

# %%
columns_list = list(Data_df.columns)
columns_list
# Out:
# ['University ID',
#  'B.S Engineering',
#  'B.S Math',
#  'B.S Computer Science',
#  'B.S Science and Tech',
#  'Region',
#  'Share of Female',
#  'Enrollment of UnderGrad',
#  'UnderGrad Population',
#  'Mean Earning After 6 yrs of Grad (0-30k)',
#  'Mean Earning After 6 yrs of Grad(30-75k)',
#  'Mean Earning After 6 yrs of Grad(75k +)',
#  'Mean Earning After 10 yrs of Grad (0-30k)',
#  'Mean Earning After 10 yrs of Grad(30-75k)',
#  'Mean Earning After 10 yrs of Grad(75k +)']

# %%
row_indices_tofilter = []
for column in columns_list:
    row_indices_tofilter.append(Data_df[Data_df[column].astype(str).str.strip()=="PrivacySuppressed"].index.tolist())
#     df[df['BoolCol'] == True].index.tolist()

new_list = []
for i in row_indices_tofilter:
    for j in i:
        new_list.append(j)
len(new_list)
filtering_set = set(new_list)
len(filtering_set)
filtering_list = list(filtering_set)
filtering_list
Data_filtered_df=Data_df.drop(filtering_list)
Data_filtered_df
# Data_filtered_df
Data_filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3811 entries, 0 to 7111
# Data columns (total 15 columns):
# University ID                                3811 non-null int64
# B.S Engineering                              3455 non-null float64
# B.S Math                                     3455 non-null float64
# B.S Computer Science                         3455 non-null float64
# B.S Science and Tech                         3455 non-null float64
# Region                                       3811 non-null int64
# Share of Female                              3481 non-null object
# Enrollment of UnderGrad                      3278 non-null float64
# UnderGrad Population                         2362 non-null float64
# Mean Earning After 6 yrs of Grad (0-30k)     2977 non-null object
# Mean Earning After 6 yrs of Grad(30-75k)     2977 non-null object
# Mean Earning After 6 yrs of Grad(75k +)      2977 non-null object
# ...

# %%
Data_no_Nan=Data_filtered_df.dropna()
Data_no_Nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2325 entries, 0 to 4834
# Data columns (total 15 columns):
# University ID                                2325 non-null int64
# B.S Engineering                              2325 non-null float64
# B.S Math                                     2325 non-null float64
# B.S Computer Science                         2325 non-null float64
# B.S Science and Tech                         2325 non-null float64
# Region                                       2325 non-null int64
# Share of Female                              2325 non-null object
# Enrollment of UnderGrad                      2325 non-null float64
# UnderGrad Population                         2325 non-null float64
# Mean Earning After 6 yrs of Grad (0-30k)     2325 non-null object
# Mean Earning After 6 yrs of Grad(30-75k)     2325 non-null object
# Mean Earning After 6 yrs of Grad(75k +)      2325 non-null object
# ...

# %%
Data_no_Nan[[
'Mean Earning After 6 yrs of Grad (0-30k)','Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)','Mean Earning After 10 yrs of Grad (0-30k)'
,'Mean Earning After 10 yrs of Grad(30-75k)',
'Mean Earning After 10 yrs of Grad(75k +)']] = Data_no_Nan[[
'Mean Earning After 6 yrs of Grad (0-30k)','Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)','Mean Earning After 10 yrs of Grad (0-30k)'
,'Mean Earning After 10 yrs of Grad(30-75k)',
'Mean Earning After 10 yrs of Grad(75k +)']].apply(pd.to_numeric)
Data_no_Nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2325 entries, 0 to 4834
# Data columns (total 15 columns):
# University ID                                2325 non-null int64
# B.S Engineering                              2325 non-null float64
# B.S Math                                     2325 non-null float64
# B.S Computer Science                         2325 non-null float64
# B.S Science and Tech                         2325 non-null float64
# Region                                       2325 non-null int64
# Share of Female                              2325 non-null object
# Enrollment of UnderGrad                      2325 non-null float64
# UnderGrad Population                         2325 non-null float64
# Mean Earning After 6 yrs of Grad (0-30k)     2325 non-null int64
# Mean Earning After 6 yrs of Grad(30-75k)     2325 non-null int64
# Mean Earning After 6 yrs of Grad(75k +)      2325 non-null int64
# Mean Earning After 10 yrs of Grad (0-30k)    2325 non-null int64
# ...

# %%
School_Offering_BS_Computer_Science  = Data_no_Nan['B.S Computer Science'].sum()
School_Offering_BS_Engineering  = Data_no_Nan['B.S Engineering'].sum()
School_Offering_BS_Math = Data_no_Nan['B.S Math'].sum()
School_Offering_BS_Science_Tech  = Data_no_Nan['B.S Science and Tech'].sum()

School_Offering_BS_Computer_Science
School_Offering_BS_Engineering 
School_Offering_BS_Math 
School_Offering_BS_Science_Tech
print(f" School_Offering_BS_Computer_Science: {School_Offering_BS_Computer_Science}\n School_Offering_BS_Math: {School_Offering_BS_Math}\nSchool_Offering_BS_Engineering: {School_Offering_BS_Engineering}\n School_Offering_BS_Science_Tech: {School_Offering_BS_Science_Tech}")
# Out:
#  School_Offering_BS_Computer_Science: 1365.0
#  School_Offering_BS_Math: 1132.0
# School_Offering_BS_Engineering: 569.0
#  School_Offering_BS_Science_Tech: 31.0

# %%
# save = Data_no_Nan.to_csv("C:/Users/phili/Desktop/Class Projet-Data.csv")
# save

# %%
Number_Of_Universities = Data_no_Nan['University ID'].count()


Perc_School_Offering_Eng = (School_Offering_BS_Engineering / Number_Of_Universities)*100
Perc_School_Offering_Math = (School_Offering_BS_Math / Number_Of_Universities)*100
Perc_School_Offering_Computer_Science = (School_Offering_BS_Computer_Science/ Number_Of_Universities)*100
Perc_School_Offering_Sci_Tech = (School_Offering_BS_Science_Tech / Number_Of_Universities)*100


Perc_School_Offering_Eng
Perc_School_Offering_Math
Perc_School_Offering_Computer_Science
Perc_School_Offering_Sci_Tech

Perc_School_Offering_Sci_Tech
# Out:
# 1.3333333333333335

# %%
Total_df = pd.DataFrame({"# Of Universities": Number_Of_Universities,
                                "%_Offering_Eng": Perc_School_Offering_Eng,
                                "%_Offering_Math": Perc_School_Offering_Math,
                                "%_Offering_Sci": Perc_School_Offering_Sci_Tech,
                                "%_Offering_CompSci": Perc_School_Offering_Computer_Science                              
                            }, index=[0])
# df = Total_df[["# Of Universities",
#                      "%_Offering_Eng",
#                      "%_Offering_Math",
#                      "%_Offering_Sci",
#                      "%_Offering_CompSci"]]

Total_df = Total_df.round(2)

Total_df.head()
# Out:
#    # Of Universities  %_Offering_Eng  %_Offering_Math  %_Offering_Sci  \
# 0               2325           24.47            48.69            1.33
#
#    %_Offering_CompSci
# 0               58.71

# %%
>>> df = pd.DataFrame({'College Degree':['%_Offering_Eng', 'Offering_Math', 'Offering_Sci','Offering_CompSci ' ], '% Offering':[569.0 , 1132.0, 31.0, 1365.0  ]})
>>> ax = df.plot.bar(x='College Degree', y='% Offering', rot=10)
ax

# %%
>>> df = pd.DataFrame({'College Degree':['%_Offering_Eng', 'Offering_Math', 'Offering_Sci','Offering_CompSci ' ], '% Offering':[24.47 , 48.69, 1.33, 58.71  ]})
>>> ax = df.plot.bar(x='College Degree', y='% Offering', rot=10)
ax

# %%
data = [[2325 , 2325 , 2325 , 2325 ],
        ['Engineering', 'Math', 'Science','Computer Science '],
        [569.0 , 1132.0, 31.0, 1365.0 ]]

rows = zip(data[0], data[1], data[2])
headers = ['# Of Colleges', 'Degree Type', 'Schools Offering']
df = pd.DataFrame(rows, columns=headers)

df
# Out:
#    # Of Colleges        Degree Type  Schools Offering
# 0           2325        Engineering             569.0
# 1           2325               Math            1132.0
# 2           2325            Science              31.0
# 3           2325  Computer Science             1365.0

# %%
Data_df = new[['University ID','B.S Engineering','B.S Math','B.S Computer Science','B.S Science and Tech','Region','Share of Female','Enrollment of UnderGrad','UnderGrad Population',
'Mean Earning After 6 yrs of Grad (0-30k)','Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)','Mean Earning After 10 yrs of Grad (0-30k)'
,'Mean Earning After 10 yrs of Grad(30-75k)',
'Mean Earning After 10 yrs of Grad(75k +)']]

Data_df.head()
# Out:
#    University ID  B.S Engineering  B.S Math  B.S Computer Science  \
# 0         100654              1.0       1.0                   1.0
# 1         100663              1.0       1.0                   1.0
# 2         100690              0.0       0.0                   0.0
# 3         100706              1.0       1.0                   1.0
# 4         100724              1.0       1.0                   1.0
#
#    B.S Science and Tech  Region Share of Female  Enrollment of UnderGrad  \
# 0                   0.0       5     0.564030132                   4824.0
# 1                   0.0       5      0.63909074                  12866.0
# 2                   0.0       5     0.648648649                    322.0
# 3                   0.0       5     0.476349937                   6917.0
# 4                   0.0       5      0.61341853                   4189.0
#
#    UnderGrad Population Mean Earning After 6 yrs of Grad (0-30k)  \
# ...

# %%
# Gender Dynamics
Data_no_Nan['Female'] = Data_no_Nan['Enrollment of UnderGrad']/Data_no_Nan['Share of Female']
Data_no_Nan['Male'] = Data_no_Nan['Enrollment of UnderGrad']-Data_no_Nan['Female']
Data_no_Nan[['Share of Female']] = Data_no_Nan[['Share of Female']].astype(float)
# Gender_Table = Data_df[['Enrollment of UnderGrad','Share of Female','Region','Female','Male']]
# Gender_Table.head()
Data_no_Nan.head()
# Out:
# C:\Users\phili\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\phili\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    University ID  B.S Engineering  B.S Math  B.S Computer Science  \
# 0         100654              1.0       1.0                   1.0
# 1         100663              1.0       1.0                   1.0
# ...

# %%
Degree_grouping = Data_no_Nan
Degree_grouping['B.S Engineering'].replace([1.0, 2.0], ['B.S. Engineering', 'B.S. Engineering'], inplace=True)
Degree_grouping['B.S Math'].replace([1.0, 2.0], ['B.S. Math', 'B.S. Math'], inplace=True)
Degree_grouping['B.S Computer Science'].replace([1.0, 2.0], ['B.S Computer Science', 'B.S Computer Science'], inplace=True)
Degree_grouping['B.S Science and Tech'].replace([1.0, 2.0], ['B.S Science and Tech', 'B.S Science and Tech'], inplace=True)

Degree_grouping.head()
# Out:
#    University ID   B.S Engineering   B.S Math  B.S Computer Science  \
# 0         100654  B.S. Engineering  B.S. Math  B.S Computer Science
# 1         100663  B.S. Engineering  B.S. Math  B.S Computer Science
# 3         100706  B.S. Engineering  B.S. Math  B.S Computer Science
# 4         100724  B.S. Engineering  B.S. Math  B.S Computer Science
# 5         100751  B.S. Engineering  B.S. Math  B.S Computer Science
#
#   B.S Science and Tech  Region  Share of Female  Enrollment of UnderGrad  \
# 0                    0       5         0.564030                   4824.0
# 1                    0       5         0.639091                  12866.0
# 3                    0       5         0.476350                   6917.0
# 4                    0       5         0.613419                   4189.0
# 5                    0       5         0.615252                  32387.0
#
#    UnderGrad Population  Mean Earning After 6 yrs of Grad (0-30k)  \
# ...

# %%
df.groupby(['Math','Region']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
# df.plot(kind='line',x='Region',y='Math',ax=ax)
# # df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)

# plt.show()

# %%
# School Offering STEM Degrees by Region

Offering_Eng_by_Eng = Data_no_Nan.groupby('Region')['B.S Engineering'].sum()
Offering_Eng_by_Math = Data_no_Nan.groupby('Region')['B.S Math'].sum()
Offering_Eng_by_CompSci = Data_no_Nan.groupby('Region')['B.S Computer Science'].sum()
Offering_Eng_by_Science = Data_no_Nan.groupby('Region')['B.S Science and Tech'].sum()
# print(f" Offering_Eng_by_Eng: {Offering_Eng_by_Eng}\n Offering_Eng_by_Math: {Offering_Eng_by_Math}\n Offering_Eng_by_CompSci: {Offering_Eng_by_CompSci}\n Offering_Eng_by_Science: {Offering_Eng_by_Science}\n")

ls = [[Offering_Eng_by_Eng, Offering_Eng_by_Math,Offering_Eng_by_CompSci,Offering_Eng_by_Science]]

df = pd.DataFrame({"Engineering": Offering_Eng_by_Eng,
                  "Math":Offering_Eng_by_Math,
                  "Computer_Science" : Offering_Eng_by_CompSci,
                  "Science": Offering_Eng_by_Science
                  })
df.head(2)
# Out:
#         Engineering   Math  Computer_Science  Science
# Region
# 1              43.0   87.0              96.0      1.0
# 2              96.0  211.0             259.0      6.0

# %%
Degree_grouping.head()
# Out:
#    University ID   B.S Engineering   B.S Math  B.S Computer Science  \
# 0         100654  B.S. Engineering  B.S. Math  B.S Computer Science
# 1         100663  B.S. Engineering  B.S. Math  B.S Computer Science
# 3         100706  B.S. Engineering  B.S. Math  B.S Computer Science
# 4         100724  B.S. Engineering  B.S. Math  B.S Computer Science
# 5         100751  B.S. Engineering  B.S. Math  B.S Computer Science
#
#   B.S Science and Tech  Region  Share of Female  Enrollment of UnderGrad  \
# 0                    0       5         0.564030                   4824.0
# 1                    0       5         0.639091                  12866.0
# 3                    0       5         0.476350                   6917.0
# 4                    0       5         0.613419                   4189.0
# 5                    0       5         0.615252                  32387.0
#
#    UnderGrad Population  Mean Earning After 6 yrs of Grad (0-30k)  \
# ...

# %%
Eng_Earning = Degree_grouping.groupby('B.S Engineering')['Mean Earning After 6 yrs of Grad (0-30k)', 'Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)'].mean()
Eng_Earning.drop(Eng_Earning.index[0], inplace=True)
Math_Earning = Degree_grouping.groupby('B.S Math')['Mean Earning After 6 yrs of Grad (0-30k)', 'Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)'].mean()
Math_Earning.drop(Math_Earning.index[0], inplace=True)

CompSci_Earning = Degree_grouping.groupby('B.S Computer Science')['Mean Earning After 6 yrs of Grad (0-30k)', 'Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)'].mean()
CompSci_Earning.drop(CompSci_Earning.index[0], inplace=True)
Science_Earning = Degree_grouping.groupby('B.S Science and Tech')['Mean Earning After 6 yrs of Grad (0-30k)', 'Mean Earning After 6 yrs of Grad(30-75k)','Mean Earning After 6 yrs of Grad(75k +)'].mean()
Science_Earning.drop(Science_Earning.index[0], inplace=True)


Combined_df=[Eng_Earning,Science_Earning,Math_Earning,CompSci_Earning]

Combined_df= pd.concat(Combined_df)
Combined_df = Combined_df.round(2)
Combined_df
# Out:
#                       Mean Earning After 6 yrs of Grad (0-30k)  \
# B.S. Engineering                                      40235.09
# B.S Science and Tech                                  35446.15
# B.S. Math                                             36842.00
# B.S Computer Science                                  35825.72
#
#                       Mean Earning After 6 yrs of Grad(30-75k)  \
# B.S. Engineering                                      42323.64
# B.S Science and Tech                                  38688.46
# B.S. Math                                             39747.75
# B.S Computer Science                                  39434.35
#
#                       Mean Earning After 6 yrs of Grad(75k +)
# B.S. Engineering                                     44930.36
# B.S Science and Tech                                 41280.77
# B.S. Math                                            42394.69
# B.S Computer Science                                 42692.13

# %%
Eng_Earning = Degree_grouping.groupby('B.S Engineering')['Mean Earning After 10 yrs of Grad (0-30k)', 'Mean Earning After 10 yrs of Grad(30-75k)','Mean Earning After 10 yrs of Grad(75k +)'].mean()
Eng_Earning.drop(Eng_Earning.index[0], inplace=True)
Math_Earning = Degree_grouping.groupby('B.S Math')['Mean Earning After 10 yrs of Grad (0-30k)', 'Mean Earning After 10 yrs of Grad(30-75k)','Mean Earning After 10 yrs of Grad(75k +)'].mean()
Math_Earning.drop(Math_Earning.index[0], inplace=True)

CompSci_Earning = Degree_grouping.groupby('B.S Computer Science')['Mean Earning After 10 yrs of Grad (0-30k)', 'Mean Earning After 10 yrs of Grad(30-75k)','Mean Earning After 10 yrs of Grad(75k +)'].mean()
CompSci_Earning.drop(CompSci_Earning.index[0], inplace=True)
Science_Earning = Degree_grouping.groupby('B.S Science and Tech')['Mean Earning After 10 yrs of Grad (0-30k)', 'Mean Earning After 10 yrs of Grad(30-75k)','Mean Earning After 10 yrs of Grad(75k +)'].mean()
Science_Earning.drop(Science_Earning.index[0], inplace=True)


Combined_ten_df=[Eng_Earning,Science_Earning,Math_Earning,CompSci_Earning]

Combined_ten_df= pd.concat(Combined_ten_df)
Combined_ten_df = Combined_ten_df.round(2)
Combined_ten_df
# Out:
#                       Mean Earning After 10 yrs of Grad (0-30k)  \
# B.S. Engineering                                       53411.09
# B.S Science and Tech                                   45734.62
# B.S. Math                                              47893.88
# B.S Computer Science                                   46754.06
#
#                       Mean Earning After 10 yrs of Grad(30-75k)  \
# B.S. Engineering                                       54734.00
# B.S Science and Tech                                   48492.31
# B.S. Math                                              50661.15
# B.S Computer Science                                   50164.81
#
#                       Mean Earning After 10 yrs of Grad(75k +)
# B.S. Engineering                                      58558.18
# B.S Science and Tech                                  52930.77
# B.S. Math                                             54439.39
# B.S Computer Science                                  54486.72

# %%
Combined_df.plot(kind='Bar',legend= True,figsize=(10,7),rot=10,title = "Mean Earning for Steam Degrees After 6 Yrs")

Combined_ten_df.plot(kind='Bar',legend= True,figsize=(10,7),rot=10,title = "Mean Earning for Steam Degrees After 10 Yrs")

# Combined_df
Combined_ten_df
# Out:
#                       Mean Earning After 10 yrs of Grad (0-30k)  \
# B.S. Engineering                                       53411.09
# B.S Science and Tech                                   45734.62
# B.S. Math                                              47893.88
# B.S Computer Science                                   46754.06
#
#                       Mean Earning After 10 yrs of Grad(30-75k)  \
# B.S. Engineering                                       54734.00
# B.S Science and Tech                                   48492.31
# B.S. Math                                              50661.15
# B.S Computer Science                                   50164.81
#
#                       Mean Earning After 10 yrs of Grad(75k +)
# B.S. Engineering                                      58558.18
# B.S Science and Tech                                  52930.77
# B.S. Math                                             54439.39
# B.S Computer Science                                  54486.72

# %%
Graphforsix = Combined_df.plot(kind='Bar',legend= True,figsize=(10,7),rot=10,title = "Mean Earnings for STEM Degrees After 6 Yrs")
plt.savefig("C:/Users/phili/Desktop/Graphforsix.png")

# %%
Graphforten = Combined_ten_df.plot(kind='Bar',legend= True,figsize=(10,7),rot=10,title = "Mean Earnings for STEM Degrees After 10 Yrs")
plt.savefig("C:/Users/phili/Desktop/Graphforten.png")
